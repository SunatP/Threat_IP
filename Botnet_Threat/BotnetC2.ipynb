# %% [markdown]
# # Import Lib now we decided to download dataset into the folder

# %%
import requests
import datetime as dt
import pandas as pd
import shutil

# %% [markdown]
# # We used requests lib for download the dataset

# %% [markdown]
# ## shutil for moving file to directory that we expect

# %%
today = dt.date.today()
url = "https://feodotracker.abuse.ch/downloads/ipblocklist_recommended.txt"
dataset = requests.get(url,allow_redirects=True)
open(("Dataset_C2.txt"),'wb').write(dataset.content)
shutil.move("Dataset_C2.txt",("Botnet_C2_dataset/Dataset_C2 "+str(today)+".txt"))
# Out:
# 'Botnet_C2_dataset/Dataset_C2 2021-10-29.txt'

# %% [markdown]
# # Edit file before create data

# %%
today = dt.date.today()
# open file
with open(("Botnet_C2_dataset/Dataset_C2 "+str(today)+".txt"),"r") as file:
    data = file.readlines()

for i in range(0,9,1): # replacing data
    print(data[i])
    data[i] = ""
data[0]= "Name\n"
# Slicing index 
print(data[-1:])
data[-1:] = ""

with open(("Botnet_C2_dataset/Dataset_C2 "+str(today)+".txt"), 'w') as file:
    file.writelines( data )
# Out:
# ################################################################
#
# # abuse.ch Feodo Tracker Botnet C2 IP Blocklist (recommended)  #
#
# # Last updated: 2021-10-29 03:12:31 UTC                        #
#
# #                                                              #
#
# # Terms Of Use: https://feodotracker.abuse.ch/blocklist/       #
#
# # For questions please contact feodotracker [at] abuse.ch      #
#
# ################################################################
#
# #
#
# # DstIP
#
# ['# END 215 entries']

# %% [markdown]
# # Use pandas for adding, editing data

# %%
df = pd.read_csv(("Botnet_C2_dataset/Dataset_C2 "+str(today)+".txt"),error_bad_lines=False)
df
# Out:
#                Name
# 0       1.234.21.73
# 1    103.109.247.13
# 2     103.109.247.8
# 3     103.109.247.9
# 4     103.127.67.38
# ..              ...
# 210    92.38.128.47
# 211    93.48.80.198
# 212     94.23.24.82
# 213    94.28.78.200
# 214  97.107.134.115
#
# [215 rows x 1 columns]

# %%
today = dt.date.today().strftime("%m/%d/%Y")
# Do not mulitply the value from existing value
df["Low IP"] = df["Name"] 
df["High IP"] = df["Name"] 
df["Malware Type"] = ["Botnet C2"] * df.shape[0]
df["Confidence"] = [" "] * df.shape[0]
df["Severity"] = [" "] * df.shape[0]
df["ASN"] = [" "] * df.shape[0]
df["Org"] = [" "] * df.shape[0]
df["Country"] = [" "] * df.shape[0]
df["Description"] = ["abuse.ch Feodo Tracker Botnet C2 IP Blocklist (recommended)"] * df.shape[0]
df["Last Seen"] = [today] * df.shape[0]
df
# Out:
#                Name          Low IP         High IP Malware Type Confidence  \
# 0       1.234.21.73     1.234.21.73     1.234.21.73    Botnet C2
# 1    103.109.247.13  103.109.247.13  103.109.247.13    Botnet C2
# 2     103.109.247.8   103.109.247.8   103.109.247.8    Botnet C2
# 3     103.109.247.9   103.109.247.9   103.109.247.9    Botnet C2
# 4     103.127.67.38   103.127.67.38   103.127.67.38    Botnet C2
# ..              ...             ...             ...          ...        ...
# 210    92.38.128.47    92.38.128.47    92.38.128.47    Botnet C2
# 211    93.48.80.198    93.48.80.198    93.48.80.198    Botnet C2
# 212     94.23.24.82     94.23.24.82     94.23.24.82    Botnet C2
# 213    94.28.78.200    94.28.78.200    94.28.78.200    Botnet C2
# 214  97.107.134.115  97.107.134.115  97.107.134.115    Botnet C2
#
#     Severity ASN Org Country  \
# 0
# 1
# 2
# 3
# 4
# ..       ...  ..  ..     ...
# 210
# 211
# 212
# 213
# 214
#
# ...

# %% [markdown]
# # Export File

# %%
today = dt.date.today()
df.to_csv ('Botnet_C2_dataset/Botnet_IP_C2 '+str(today)+".csv", index = False, header=True, encoding="utf-8-sig")
print("OK at",today)
# Out:
# OK at 2021-10-29
